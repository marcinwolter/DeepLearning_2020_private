# %% [markdown]
# <a href="https://colab.research.google.com/github/marcinwolter/DeepLearning_2020_private/blob/main/MDN_1D_sine_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Mixture Density Network
#
# Reproducing the classic Bishop MDN network tasks in Keras. The idea in this task is to predict a the value of an inverse sine function. This function has multiple real-valued solutions at each point, so the ANN model needs to have the capacity to handle this in it's loss function. An MDN is a good way to handle the predictions of these multiple output values.
#
# There's a couple of other versions of this task, and this implementation owes much to the following:
#
# - [David Ha - Mixture Density Networks with TensorFlow](http://blog.otoro.net/2015/11/24/mixture-density-networks-with-tensorflow/)
# - [Mixture Density Networks in Edward](http://edwardlib.org/tutorials/mixture-density-network)

# %%
#!pip install git+git://github.com/cpmpercussion/keras-mdn-layer.git#egg=keras-mdn-layer
# !pip install keras-mdn-layer
###!python3 -m pip install keras-mdn-layer

from tensorflow.compat.v1 import keras
###import keras
import mdn
#from context import * # imports the MDN layer 
import numpy as np
import random
import matplotlib.pyplot as plt
#%matplotlib notebook
# Out:
# Requirement already satisfied: keras-mdn-layer in /usr/local/lib/python3.6/dist-packages (0.3.0)

# %% [markdown]
# ## Generate Synthetic Data
#
# Data generation

# %%
## Generating some data:
NSAMPLE = 3000

'''
y_data = np.float32(np.random.uniform(-10.5, 10.5, NSAMPLE))
r_data = np.random.normal(size=NSAMPLE)
x_data = np.sin(0.75 * y_data) * 7.0 + y_data * 0.5 + r_data * 1.0
x_data = x_data.reshape((NSAMPLE, 1))
'''
x_data = np.float32(np.random.uniform(-10.5, 10.5, NSAMPLE))
r_data = np.random.normal(size=NSAMPLE)
y_data = 0.05*x_data*x_data + r_data*np.sin(0.3*x_data)*5.
x_data = x_data.reshape((NSAMPLE, 1))


plt.figure(figsize=(8, 8))
plt.plot(x_data,y_data,'ro', alpha=0.3)
plt.show()

# %% [markdown]
# ## Build the MDN Model
#
# Now we will construct the MDN model in Keras. This uses the `Sequential` model interface in Keras.
#
# The `MDN` layer comes after one or more `Dense` layers. You need to define the output dimension and number of mixtures for the MDN like so: `MDN(output_dimension, number_mixtures)`.
#
# For this problem, we only need an output dimension of 1 as we are predicting one value (y). Adding more mixtures adds a more parameters (model is more complex, takes longer to train), but might help make the solutions better. You can see from the training data that there are at maximum 5 different layers to predict in the curve, so setting `N_MIXES = 5` is a good place to start.
#
# For MDNs, we have to use a special loss function that can handle the mixture parameters: the function has to take into account the number of output dimensions and mixtures.

# %%
N_HIDDEN = 15
N_MIXES = 3  #5

model = keras.Sequential()
model.add(keras.layers.Dense(N_HIDDEN, batch_input_shape=(None, 1), activation='relu'))
model.add(keras.layers.Dense(N_HIDDEN, activation='relu'))
model.add(mdn.MDN(1, N_MIXES))

model.compile(loss=mdn.get_mixture_loss_func(1,N_MIXES), optimizer=keras.optimizers.Adam()) #, metrics=[mdn.get_mixture_mse_accuracy(1,N_MIXES)])
model.summary()
# Out:
# Model: "sequential_16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_32 (Dense)             (None, 15)                30
# _________________________________________________________________
# dense_33 (Dense)             (None, 15)                240
# _________________________________________________________________
# mdn_16 (MDN)                 (None, 9)                 144
# =================================================================
# Total params: 414
# Trainable params: 414
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Training the model
#
# Now we train the model using Keras' normal `fit` command.

# %%
history = model.fit(x=x_data, y=y_data, batch_size=128, epochs=400, validation_split=0.15)
# Out:
# Epoch 1/400
# 20/20 [==============================] - 3s 38ms/step - loss: 3.4483 - val_loss: 2.8180
# Epoch 2/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.8481 - val_loss: 2.6478
# Epoch 3/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.6822 - val_loss: 2.5893
# Epoch 4/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.6562 - val_loss: 2.5758
# Epoch 5/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.6438 - val_loss: 2.5654
# Epoch 6/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.6206 - val_loss: 2.5578
# Epoch 7/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.6080 - val_loss: 2.5508
# Epoch 8/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.6035 - val_loss: 2.5465
# Epoch 9/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.5827 - val_loss: 2.5468
# Epoch 10/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.6279 - val_loss: 2.5421
# Epoch 11/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.6218 - val_loss: 2.5379
# Epoch 12/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.6086 - val_loss: 2.5360
# Epoch 13/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.5948 - val_loss: 2.5351
# Epoch 14/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.6085 - val_loss: 2.5317
# Epoch 15/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.6026 - val_loss: 2.5307
# Epoch 16/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.5954 - val_loss: 2.5228
# Epoch 17/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.5949 - val_loss: 2.5210
# Epoch 18/400
# 20/20 [==============================] - 1s 38ms/step - loss: 2.5602 - val_loss: 2.5146
# Epoch 19/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.5716 - val_loss: 2.5101
# Epoch 20/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.5428 - val_loss: 2.5093
# Epoch 21/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.5562 - val_loss: 2.5022
# Epoch 22/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.5409 - val_loss: 2.5016
# Epoch 23/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.5413 - val_loss: 2.4943
# Epoch 24/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.5418 - val_loss: 2.4935
# Epoch 25/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.5083 - val_loss: 2.4928
# Epoch 26/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.5357 - val_loss: 2.4866
# Epoch 27/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.5489 - val_loss: 2.4866
# Epoch 28/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.5158 - val_loss: 2.4819
# Epoch 29/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.5365 - val_loss: 2.4815
# Epoch 30/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.5309 - val_loss: 2.4809
# Epoch 31/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.5301 - val_loss: 2.4796
# Epoch 32/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.5557 - val_loss: 2.4723
# Epoch 33/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.4950 - val_loss: 2.4771
# Epoch 34/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.4932 - val_loss: 2.4714
# Epoch 35/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.5095 - val_loss: 2.4740
# Epoch 36/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.5143 - val_loss: 2.4696
# Epoch 37/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.5285 - val_loss: 2.4687
# Epoch 38/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.4908 - val_loss: 2.4677
# Epoch 39/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.5150 - val_loss: 2.4647
# Epoch 40/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.5036 - val_loss: 2.4641
# Epoch 41/400
# 20/20 [==============================] - 0s 9ms/step - loss: 2.4834 - val_loss: 2.4603
# Epoch 42/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.4988 - val_loss: 2.4633
# Epoch 43/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.5171 - val_loss: 2.4641
# Epoch 44/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.4810 - val_loss: 2.4576
# Epoch 45/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.4921 - val_loss: 2.4549
# Epoch 46/400
# 20/20 [==============================] - 0s 10ms/step - loss: 2.4956 - val_loss: 2.4566
# Epoch 47/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.5047 - val_loss: 2.4564
# Epoch 48/400
# 20/20 [==============================] - 0s 9ms/step - loss: 2.4687 - val_loss: 2.4523
# Epoch 49/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.4878 - val_loss: 2.4499
# Epoch 50/400
# 20/20 [==============================] - 0s 9ms/step - loss: 2.4812 - val_loss: 2.4529
# Epoch 51/400
# 20/20 [==============================] - 0s 10ms/step - loss: 2.4790 - val_loss: 2.4489
# Epoch 52/400
# 20/20 [==============================] - 0s 10ms/step - loss: 2.4687 - val_loss: 2.4465
# Epoch 53/400
# 20/20 [==============================] - 0s 9ms/step - loss: 2.4782 - val_loss: 2.4455
# Epoch 54/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.4733 - val_loss: 2.4425
# Epoch 55/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.4784 - val_loss: 2.4411
# Epoch 56/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.5007 - val_loss: 2.4400
# Epoch 57/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.4914 - val_loss: 2.4394
# Epoch 58/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.4698 - val_loss: 2.4376
# Epoch 59/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.4648 - val_loss: 2.4399
# Epoch 60/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.4824 - val_loss: 2.4387
# Epoch 61/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.4594 - val_loss: 2.4311
# Epoch 62/400
# 20/20 [==============================] - 0s 10ms/step - loss: 2.4465 - val_loss: 2.4359
# Epoch 63/400
# 20/20 [==============================] - 0s 9ms/step - loss: 2.4729 - val_loss: 2.4229
# Epoch 64/400
# 20/20 [==============================] - 0s 10ms/step - loss: 2.4359 - val_loss: 2.4264
# Epoch 65/400
# 20/20 [==============================] - 0s 9ms/step - loss: 2.4306 - val_loss: 2.4229
# Epoch 66/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.4695 - val_loss: 2.4206
# Epoch 67/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.4498 - val_loss: 2.4253
# Epoch 68/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.4620 - val_loss: 2.4217
# Epoch 69/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.4464 - val_loss: 2.4254
# Epoch 70/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.4693 - val_loss: 2.4176
# Epoch 71/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.4215 - val_loss: 2.4184
# Epoch 72/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.4690 - val_loss: 2.4122
# Epoch 73/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.4286 - val_loss: 2.4161
# Epoch 74/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.4589 - val_loss: 2.4168
# Epoch 75/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.4462 - val_loss: 2.4123
# Epoch 76/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.4056 - val_loss: 2.4095
# Epoch 77/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.4438 - val_loss: 2.4073
# Epoch 78/400
# 20/20 [==============================] - 0s 17ms/step - loss: 2.4316 - val_loss: 2.4071
# Epoch 79/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.4477 - val_loss: 2.4020
# Epoch 80/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.4371 - val_loss: 2.4084
# Epoch 81/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.4511 - val_loss: 2.4030
# Epoch 82/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.4086 - val_loss: 2.3982
# Epoch 83/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.4351 - val_loss: 2.3969
# Epoch 84/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.4681 - val_loss: 2.4026
# Epoch 85/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.4382 - val_loss: 2.3929
# Epoch 86/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.4205 - val_loss: 2.3978
# Epoch 87/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.4055 - val_loss: 2.3982
# Epoch 88/400
# 20/20 [==============================] - 0s 9ms/step - loss: 2.4096 - val_loss: 2.3970
# Epoch 89/400
# 20/20 [==============================] - 0s 9ms/step - loss: 2.4148 - val_loss: 2.3947
# Epoch 90/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.4001 - val_loss: 2.3930
# Epoch 91/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.4304 - val_loss: 2.4020
# Epoch 92/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.4236 - val_loss: 2.4032
# Epoch 93/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.4081 - val_loss: 2.3817
# Epoch 94/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.4073 - val_loss: 2.3901
# Epoch 95/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.4492 - val_loss: 2.3931
# Epoch 96/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3761 - val_loss: 2.3827
# Epoch 97/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3766 - val_loss: 2.3829
# Epoch 98/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3929 - val_loss: 2.3805
# Epoch 99/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.4309 - val_loss: 2.3741
# Epoch 100/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.4172 - val_loss: 2.3824
# Epoch 101/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.4097 - val_loss: 2.3847
# Epoch 102/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3765 - val_loss: 2.3702
# Epoch 103/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3907 - val_loss: 2.3725
# Epoch 104/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3994 - val_loss: 2.3715
# Epoch 105/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3985 - val_loss: 2.3727
# Epoch 106/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3786 - val_loss: 2.3728
# Epoch 107/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3910 - val_loss: 2.3732
# Epoch 108/400
# 20/20 [==============================] - 0s 9ms/step - loss: 2.3996 - val_loss: 2.3709
# Epoch 109/400
# 20/20 [==============================] - 0s 9ms/step - loss: 2.4316 - val_loss: 2.3731
# Epoch 110/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3928 - val_loss: 2.3730
# Epoch 111/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3711 - val_loss: 2.3730
# Epoch 112/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.4232 - val_loss: 2.3692
# Epoch 113/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.4102 - val_loss: 2.3768
# Epoch 114/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.4031 - val_loss: 2.3805
# Epoch 115/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3978 - val_loss: 2.3690
# Epoch 116/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.4084 - val_loss: 2.3741
# Epoch 117/400
# 20/20 [==============================] - 0s 16ms/step - loss: 2.3833 - val_loss: 2.3637
# Epoch 118/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3782 - val_loss: 2.3643
# Epoch 119/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.4100 - val_loss: 2.3610
# Epoch 120/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.4011 - val_loss: 2.3694
# Epoch 121/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.4061 - val_loss: 2.3596
# Epoch 122/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3994 - val_loss: 2.3593
# Epoch 123/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.4015 - val_loss: 2.3646
# Epoch 124/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.4112 - val_loss: 2.3704
# Epoch 125/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3850 - val_loss: 2.3570
# Epoch 126/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.4064 - val_loss: 2.3558
# Epoch 127/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3837 - val_loss: 2.3675
# Epoch 128/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3993 - val_loss: 2.3650
# Epoch 129/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.4316 - val_loss: 2.3645
# Epoch 130/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3928 - val_loss: 2.3678
# Epoch 131/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.4070 - val_loss: 2.3571
# Epoch 132/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3857 - val_loss: 2.3528
# Epoch 133/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3842 - val_loss: 2.3632
# Epoch 134/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3808 - val_loss: 2.3630
# Epoch 135/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.4056 - val_loss: 2.3525
# Epoch 136/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3931 - val_loss: 2.3487
# Epoch 137/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3648 - val_loss: 2.3532
# Epoch 138/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3862 - val_loss: 2.3643
# Epoch 139/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3514 - val_loss: 2.3560
# Epoch 140/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3892 - val_loss: 2.3592
# Epoch 141/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3579 - val_loss: 2.3734
# Epoch 142/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3851 - val_loss: 2.3514
# Epoch 143/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3910 - val_loss: 2.3477
# Epoch 144/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3691 - val_loss: 2.3487
# Epoch 145/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.4043 - val_loss: 2.3531
# Epoch 146/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3803 - val_loss: 2.3459
# Epoch 147/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3897 - val_loss: 2.3460
# Epoch 148/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3765 - val_loss: 2.3470
# Epoch 149/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.4023 - val_loss: 2.3605
# Epoch 150/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.4015 - val_loss: 2.3497
# Epoch 151/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3841 - val_loss: 2.3531
# Epoch 152/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3717 - val_loss: 2.3504
# Epoch 153/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3502 - val_loss: 2.3593
# Epoch 154/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3994 - val_loss: 2.3464
# Epoch 155/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3516 - val_loss: 2.3491
# Epoch 156/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3867 - val_loss: 2.3428
# Epoch 157/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3829 - val_loss: 2.3484
# Epoch 158/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3694 - val_loss: 2.3423
# Epoch 159/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3616 - val_loss: 2.3477
# Epoch 160/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.4111 - val_loss: 2.3466
# Epoch 161/400
# 20/20 [==============================] - 0s 9ms/step - loss: 2.3620 - val_loss: 2.3435
# Epoch 162/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3706 - val_loss: 2.3436
# Epoch 163/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3836 - val_loss: 2.3407
# Epoch 164/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3893 - val_loss: 2.3467
# Epoch 165/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3958 - val_loss: 2.3470
# Epoch 166/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3506 - val_loss: 2.3474
# Epoch 167/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3900 - val_loss: 2.3399
# Epoch 168/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.4105 - val_loss: 2.3431
# Epoch 169/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.4064 - val_loss: 2.3424
# Epoch 170/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3757 - val_loss: 2.3474
# Epoch 171/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3422 - val_loss: 2.3424
# Epoch 172/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3533 - val_loss: 2.3364
# Epoch 173/400
# 20/20 [==============================] - 0s 9ms/step - loss: 2.3867 - val_loss: 2.3551
# Epoch 174/400
# 20/20 [==============================] - 0s 9ms/step - loss: 2.3616 - val_loss: 2.3369
# Epoch 175/400
# 20/20 [==============================] - 0s 18ms/step - loss: 2.3647 - val_loss: 2.3453
# Epoch 176/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3398 - val_loss: 2.3522
# Epoch 177/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3615 - val_loss: 2.3544
# Epoch 178/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3871 - val_loss: 2.3341
# Epoch 179/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3734 - val_loss: 2.3420
# Epoch 180/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3531 - val_loss: 2.3368
# Epoch 181/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3500 - val_loss: 2.3472
# Epoch 182/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3655 - val_loss: 2.3380
# Epoch 183/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3662 - val_loss: 2.3523
# Epoch 184/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3462 - val_loss: 2.3353
# Epoch 185/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3836 - val_loss: 2.3440
# Epoch 186/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3628 - val_loss: 2.3340
# Epoch 187/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3704 - val_loss: 2.3370
# Epoch 188/400
# 20/20 [==============================] - 0s 10ms/step - loss: 2.3868 - val_loss: 2.3388
# Epoch 189/400
# 20/20 [==============================] - 0s 11ms/step - loss: 2.3679 - val_loss: 2.3303
# Epoch 190/400
# 20/20 [==============================] - 0s 9ms/step - loss: 2.3668 - val_loss: 2.3394
# Epoch 191/400
# 20/20 [==============================] - 0s 10ms/step - loss: 2.4031 - val_loss: 2.3399
# Epoch 192/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3922 - val_loss: 2.3345
# Epoch 193/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3899 - val_loss: 2.3353
# Epoch 194/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3538 - val_loss: 2.3364
# Epoch 195/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3886 - val_loss: 2.3412
# Epoch 196/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3575 - val_loss: 2.3419
# Epoch 197/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3501 - val_loss: 2.3317
# Epoch 198/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3508 - val_loss: 2.3322
# Epoch 199/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3968 - val_loss: 2.3386
# Epoch 200/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3618 - val_loss: 2.3333
# Epoch 201/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3630 - val_loss: 2.3293
# Epoch 202/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3781 - val_loss: 2.3397
# Epoch 203/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3359 - val_loss: 2.3355
# Epoch 204/400
# 20/20 [==============================] - 0s 9ms/step - loss: 2.3701 - val_loss: 2.3363
# Epoch 205/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3590 - val_loss: 2.3420
# Epoch 206/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.4024 - val_loss: 2.3307
# Epoch 207/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3566 - val_loss: 2.3329
# Epoch 208/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3771 - val_loss: 2.3311
# Epoch 209/400
# 20/20 [==============================] - 0s 10ms/step - loss: 2.3498 - val_loss: 2.3399
# Epoch 210/400
# 20/20 [==============================] - 0s 9ms/step - loss: 2.3825 - val_loss: 2.3312
# Epoch 211/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3577 - val_loss: 2.3383
# Epoch 212/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3841 - val_loss: 2.3448
# Epoch 213/400
# 20/20 [==============================] - 0s 9ms/step - loss: 2.3589 - val_loss: 2.3412
# Epoch 214/400
# 20/20 [==============================] - 0s 10ms/step - loss: 2.3647 - val_loss: 2.3281
# Epoch 215/400
# 20/20 [==============================] - 0s 10ms/step - loss: 2.3594 - val_loss: 2.3357
# Epoch 216/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3853 - val_loss: 2.3285
# Epoch 217/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3434 - val_loss: 2.3343
# Epoch 218/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3520 - val_loss: 2.3295
# Epoch 219/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3637 - val_loss: 2.3397
# Epoch 220/400
# 20/20 [==============================] - 0s 16ms/step - loss: 2.3504 - val_loss: 2.3378
# Epoch 221/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3589 - val_loss: 2.3389
# Epoch 222/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3455 - val_loss: 2.3318
# Epoch 223/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3478 - val_loss: 2.3478
# Epoch 224/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3652 - val_loss: 2.3320
# Epoch 225/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3162 - val_loss: 2.3420
# Epoch 226/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3694 - val_loss: 2.3422
# Epoch 227/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3583 - val_loss: 2.3275
# Epoch 228/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3830 - val_loss: 2.3309
# Epoch 229/400
# 20/20 [==============================] - 0s 9ms/step - loss: 2.3882 - val_loss: 2.3356
# Epoch 230/400
# 20/20 [==============================] - 0s 9ms/step - loss: 2.3771 - val_loss: 2.3281
# Epoch 231/400
# 20/20 [==============================] - 0s 9ms/step - loss: 2.3605 - val_loss: 2.3425
# Epoch 232/400
# 20/20 [==============================] - 0s 10ms/step - loss: 2.3584 - val_loss: 2.3317
# Epoch 233/400
# 20/20 [==============================] - 0s 9ms/step - loss: 2.3579 - val_loss: 2.3298
# Epoch 234/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3457 - val_loss: 2.3292
# Epoch 235/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3447 - val_loss: 2.3327
# Epoch 236/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3339 - val_loss: 2.3295
# Epoch 237/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3683 - val_loss: 2.3251
# Epoch 238/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3528 - val_loss: 2.3298
# Epoch 239/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3366 - val_loss: 2.3316
# Epoch 240/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3579 - val_loss: 2.3269
# Epoch 241/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3527 - val_loss: 2.3272
# Epoch 242/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3968 - val_loss: 2.3343
# Epoch 243/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3614 - val_loss: 2.3601
# Epoch 244/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3424 - val_loss: 2.3359
# Epoch 245/400
# 20/20 [==============================] - 0s 9ms/step - loss: 2.3559 - val_loss: 2.3265
# Epoch 246/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3739 - val_loss: 2.3357
# Epoch 247/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3977 - val_loss: 2.3424
# Epoch 248/400
# 20/20 [==============================] - 0s 9ms/step - loss: 2.3611 - val_loss: 2.3308
# Epoch 249/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3313 - val_loss: 2.3311
# Epoch 250/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3672 - val_loss: 2.3286
# Epoch 251/400
# 20/20 [==============================] - 0s 9ms/step - loss: 2.3557 - val_loss: 2.3298
# Epoch 252/400
# 20/20 [==============================] - 0s 10ms/step - loss: 2.3144 - val_loss: 2.3232
# Epoch 253/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3556 - val_loss: 2.3259
# Epoch 254/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3276 - val_loss: 2.3262
# Epoch 255/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3675 - val_loss: 2.3219
# Epoch 256/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3445 - val_loss: 2.3278
# Epoch 257/400
# 20/20 [==============================] - 0s 9ms/step - loss: 2.3573 - val_loss: 2.3307
# Epoch 258/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3648 - val_loss: 2.3249
# Epoch 259/400
# 20/20 [==============================] - 0s 18ms/step - loss: 2.3411 - val_loss: 2.3285
# Epoch 260/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3532 - val_loss: 2.3359
# Epoch 261/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3585 - val_loss: 2.3236
# Epoch 262/400
# 20/20 [==============================] - 0s 9ms/step - loss: 2.3306 - val_loss: 2.3336
# Epoch 263/400
# 20/20 [==============================] - 0s 9ms/step - loss: 2.3550 - val_loss: 2.3281
# Epoch 264/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3387 - val_loss: 2.3306
# Epoch 265/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3598 - val_loss: 2.3304
# Epoch 266/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3575 - val_loss: 2.3325
# Epoch 267/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3729 - val_loss: 2.3307
# Epoch 268/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3393 - val_loss: 2.3226
# Epoch 269/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3224 - val_loss: 2.3252
# Epoch 270/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3397 - val_loss: 2.3246
# Epoch 271/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3295 - val_loss: 2.3253
# Epoch 272/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3351 - val_loss: 2.3213
# Epoch 273/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3627 - val_loss: 2.3324
# Epoch 274/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3330 - val_loss: 2.3294
# Epoch 275/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3728 - val_loss: 2.3347
# Epoch 276/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3717 - val_loss: 2.3269
# Epoch 277/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3417 - val_loss: 2.3293
# Epoch 278/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3814 - val_loss: 2.3373
# Epoch 279/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3730 - val_loss: 2.3363
# Epoch 280/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3323 - val_loss: 2.3278
# Epoch 281/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3304 - val_loss: 2.3219
# Epoch 282/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3336 - val_loss: 2.3244
# Epoch 283/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3393 - val_loss: 2.3200
# Epoch 284/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3345 - val_loss: 2.3247
# Epoch 285/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3081 - val_loss: 2.3239
# Epoch 286/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3478 - val_loss: 2.3367
# Epoch 287/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3663 - val_loss: 2.3204
# Epoch 288/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3498 - val_loss: 2.3309
# Epoch 289/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3351 - val_loss: 2.3271
# Epoch 290/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3778 - val_loss: 2.3376
# Epoch 291/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3509 - val_loss: 2.3206
# Epoch 292/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3404 - val_loss: 2.3452
# Epoch 293/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3381 - val_loss: 2.3447
# Epoch 294/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3656 - val_loss: 2.3222
# Epoch 295/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3476 - val_loss: 2.3231
# Epoch 296/400
# 20/20 [==============================] - 0s 9ms/step - loss: 2.3280 - val_loss: 2.3341
# Epoch 297/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3747 - val_loss: 2.3249
# Epoch 298/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3128 - val_loss: 2.3200
# Epoch 299/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3395 - val_loss: 2.3226
# Epoch 300/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3420 - val_loss: 2.3306
# Epoch 301/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3594 - val_loss: 2.3306
# Epoch 302/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3515 - val_loss: 2.3306
# Epoch 303/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3424 - val_loss: 2.3233
# Epoch 304/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3575 - val_loss: 2.3350
# Epoch 305/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3322 - val_loss: 2.3372
# Epoch 306/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3206 - val_loss: 2.3244
# Epoch 307/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3512 - val_loss: 2.3223
# Epoch 308/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3678 - val_loss: 2.3277
# Epoch 309/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.4039 - val_loss: 2.3296
# Epoch 310/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3515 - val_loss: 2.3221
# Epoch 311/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3358 - val_loss: 2.3328
# Epoch 312/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3745 - val_loss: 2.3285
# Epoch 313/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.4028 - val_loss: 2.3358
# Epoch 314/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3360 - val_loss: 2.3204
# Epoch 315/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3368 - val_loss: 2.3244
# Epoch 316/400
# 20/20 [==============================] - 0s 18ms/step - loss: 2.3833 - val_loss: 2.3271
# Epoch 317/400
# 20/20 [==============================] - 0s 9ms/step - loss: 2.3451 - val_loss: 2.3266
# Epoch 318/400
# 20/20 [==============================] - 0s 10ms/step - loss: 2.3314 - val_loss: 2.3248
# Epoch 319/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3677 - val_loss: 2.3229
# Epoch 320/400
# 20/20 [==============================] - 0s 10ms/step - loss: 2.3819 - val_loss: 2.3233
# Epoch 321/400
# 20/20 [==============================] - 0s 10ms/step - loss: 2.3520 - val_loss: 2.3245
# Epoch 322/400
# 20/20 [==============================] - 0s 10ms/step - loss: 2.3435 - val_loss: 2.3322
# Epoch 323/400
# 20/20 [==============================] - 0s 10ms/step - loss: 2.3666 - val_loss: 2.3258
# Epoch 324/400
# 20/20 [==============================] - 0s 10ms/step - loss: 2.3268 - val_loss: 2.3257
# Epoch 325/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3247 - val_loss: 2.3189
# Epoch 326/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3499 - val_loss: 2.3223
# Epoch 327/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3406 - val_loss: 2.3295
# Epoch 328/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3689 - val_loss: 2.3412
# Epoch 329/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3754 - val_loss: 2.3351
# Epoch 330/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3406 - val_loss: 2.3201
# Epoch 331/400
# 20/20 [==============================] - 0s 9ms/step - loss: 2.3170 - val_loss: 2.3249
# Epoch 332/400
# 20/20 [==============================] - 0s 9ms/step - loss: 2.3617 - val_loss: 2.3226
# Epoch 333/400
# 20/20 [==============================] - 0s 9ms/step - loss: 2.3579 - val_loss: 2.3237
# Epoch 334/400
# 20/20 [==============================] - 0s 9ms/step - loss: 2.3140 - val_loss: 2.3205
# Epoch 335/400
# 20/20 [==============================] - 0s 9ms/step - loss: 2.3375 - val_loss: 2.3316
# Epoch 336/400
# 20/20 [==============================] - 0s 10ms/step - loss: 2.3512 - val_loss: 2.3203
# Epoch 337/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3441 - val_loss: 2.3153
# Epoch 338/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3426 - val_loss: 2.3292
# Epoch 339/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3397 - val_loss: 2.3235
# Epoch 340/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.2965 - val_loss: 2.3196
# Epoch 341/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3560 - val_loss: 2.3215
# Epoch 342/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3287 - val_loss: 2.3412
# Epoch 343/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3474 - val_loss: 2.3331
# Epoch 344/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3691 - val_loss: 2.3142
# Epoch 345/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3290 - val_loss: 2.3220
# Epoch 346/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3537 - val_loss: 2.3319
# Epoch 347/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3404 - val_loss: 2.3198
# Epoch 348/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3290 - val_loss: 2.3166
# Epoch 349/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3515 - val_loss: 2.3267
# Epoch 350/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3533 - val_loss: 2.3207
# Epoch 351/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3413 - val_loss: 2.3169
# Epoch 352/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3242 - val_loss: 2.3334
# Epoch 353/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3745 - val_loss: 2.3217
# Epoch 354/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.2787 - val_loss: 2.3232
# Epoch 355/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3446 - val_loss: 2.3217
# Epoch 356/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3581 - val_loss: 2.3340
# Epoch 357/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3608 - val_loss: 2.3243
# Epoch 358/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3361 - val_loss: 2.3162
# Epoch 359/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3446 - val_loss: 2.3207
# Epoch 360/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3175 - val_loss: 2.3285
# Epoch 361/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3467 - val_loss: 2.3272
# Epoch 362/400
# 20/20 [==============================] - 0s 16ms/step - loss: 2.3603 - val_loss: 2.3185
# Epoch 363/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3135 - val_loss: 2.3168
# Epoch 364/400
# 20/20 [==============================] - 0s 9ms/step - loss: 2.3340 - val_loss: 2.3347
# Epoch 365/400
# 20/20 [==============================] - 0s 10ms/step - loss: 2.3609 - val_loss: 2.3157
# Epoch 366/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3379 - val_loss: 2.3398
# Epoch 367/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3597 - val_loss: 2.3205
# Epoch 368/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3426 - val_loss: 2.3217
# Epoch 369/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3484 - val_loss: 2.3309
# Epoch 370/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3481 - val_loss: 2.3219
# Epoch 371/400
# 20/20 [==============================] - 0s 9ms/step - loss: 2.3930 - val_loss: 2.3159
# Epoch 372/400
# 20/20 [==============================] - 0s 9ms/step - loss: 2.3451 - val_loss: 2.3213
# Epoch 373/400
# 20/20 [==============================] - 0s 9ms/step - loss: 2.3376 - val_loss: 2.3227
# Epoch 374/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3477 - val_loss: 2.3148
# Epoch 375/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3384 - val_loss: 2.3247
# Epoch 376/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3369 - val_loss: 2.3221
# Epoch 377/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3092 - val_loss: 2.3263
# Epoch 378/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3340 - val_loss: 2.3245
# Epoch 379/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3350 - val_loss: 2.3298
# Epoch 380/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3231 - val_loss: 2.3231
# Epoch 381/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3505 - val_loss: 2.3241
# Epoch 382/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3677 - val_loss: 2.3172
# Epoch 383/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3410 - val_loss: 2.3227
# Epoch 384/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3099 - val_loss: 2.3272
# Epoch 385/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3725 - val_loss: 2.3315
# Epoch 386/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3739 - val_loss: 2.3236
# Epoch 387/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3460 - val_loss: 2.3287
# Epoch 388/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3575 - val_loss: 2.3239
# Epoch 389/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3541 - val_loss: 2.3247
# Epoch 390/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3553 - val_loss: 2.3151
# Epoch 391/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3318 - val_loss: 2.3255
# Epoch 392/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3347 - val_loss: 2.3174
# Epoch 393/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3560 - val_loss: 2.3184
# Epoch 394/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3109 - val_loss: 2.3190
# Epoch 395/400
# 20/20 [==============================] - 0s 9ms/step - loss: 2.3120 - val_loss: 2.3165
# Epoch 396/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3414 - val_loss: 2.3165
# Epoch 397/400
# 20/20 [==============================] - 0s 10ms/step - loss: 2.3478 - val_loss: 2.3188
# Epoch 398/400
# 20/20 [==============================] - 0s 8ms/step - loss: 2.3677 - val_loss: 2.3198
# Epoch 399/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3359 - val_loss: 2.3252
# Epoch 400/400
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3464 - val_loss: 2.3223

# %%
# Save model if you want to.
# model.save("MDN-1D-sine-prediction-model.h5")

# %%
# Load the model if you want to.
# To load models from file, you need to supply the layer and loss function as custom_objects:
# model = keras.models.load_model('MDN-1D-sine-prediction-model.h5', custom_objects={'MDN': mdn.MDN, 'loss_func': mdn.get_mixture_loss_func(1, N_MIXES)})

# %% [markdown]
# ### Training and Validation Loss
#
# It's interesting to see how the model trained. We can see that after a certain point training is rather slow.
#
# For this problem a loss value around 1.5 produces quite good results.

# %%
plt.figure(figsize=(10, 5))
plt.ylim([0,9])
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.show()

# %% [markdown]
# ## Sampling Functions
#
# The MDN model outputs parameters of a mixture model---a list of means (mu), variances (sigma), and weights (pi).
#
# The `mdn` module provides a function to sample from these parameters as follows. First the parameters are split up into `mu`s, `sigma`s and `pi`s, then the categorical distribution formed by the `pi`s is sampled to choose which mixture component should be sampled, then that component's `mu`s and `sigma`s is used to sample from a multivariate normal model, here's the code:
#
#     def sample_from_output(params, output_dim, num_mixes, temp=1.0):
#         """Sample from an MDN output with temperature adjustment."""
#         mus = params[:num_mixes*output_dim]
#         sigs = params[num_mixes*output_dim:2*num_mixes*output_dim]
#         pis = softmax(params[-num_mixes:], t=temp)
#         m = sample_from_categorical(pis)
#         # Alternative way to sample from categorical:
#         # m = np.random.choice(range(len(pis)), p=pis)
#         mus_vector = mus[m*output_dim:(m+1)*output_dim]
#         sig_vector = sigs[m*output_dim:(m+1)*output_dim] * temp  # adjust for temperature
#         cov_matrix = np.identity(output_dim) * sig_vector
#         sample = np.random.multivariate_normal(mus_vector, cov_matrix, 1)
#         return sample
#
# If you only have one prediction to sample from, you can use the function as is; but if you need to sample from a lot of predictions at once (as in the following sections), you can use `np.apply_along_axis` to apply it to a whole numpy array of predicted parameters.

# %% [markdown]
# ## Try out the MDN Model
#
# Now we try out the model by making predictions at 3000 evenly spaced points on the x-axis.
#
# Mixture models output lists of parameters, so we're going to sample from these parameters for each point on the x-axis, and also try plotting the parameters themselves so we can have some insight into what the model is learning!

# %%
## Sample on some test data:
x_test = np.float32(np.arange(-15,15,0.01))
NTEST = x_test.size
print("Testing:", NTEST, "samples.")
x_test = x_test.reshape(NTEST,1) # needs to be a matrix, not a vector

# Make predictions from the model
y_test = model.predict(x_test)
# y_test contains parameters for distributions, not actual points on the graph.
# To find points on the graph, we need to sample from each distribution.

# Sample from the predicted distributions
y_samples = np.apply_along_axis(mdn.sample_from_output, 1, y_test, 1, N_MIXES,temp=1.0)

# Split up the mixture parameters (for future fun)
mus = np.apply_along_axis((lambda a: a[:N_MIXES]),1, y_test)
sigs = np.apply_along_axis((lambda a: a[N_MIXES:2*N_MIXES]),1, y_test)
pis = np.apply_along_axis((lambda a: mdn.softmax(a[2*N_MIXES:])),1, y_test)
# Out:
# Testing: 3000 samples.

# %%
# Plot the samples
plt.figure(figsize=(8, 8))
plt.plot(x_data,y_data,'ro', x_test, y_samples[:,:,0], 'bo',alpha=0.3)
plt.show()
# These look pretty good!

# %%
# Plot the means - this gives us some insight into how the model learns to produce the mixtures.
plt.figure(figsize=(8, 8))
plt.plot(x_data,y_data,'ro', x_test, mus,'bo',alpha=0.3)
plt.show()
# Cool!

# %%
# Let's plot the variances and weightings of the means as well.
fig = plt.figure(figsize=(8, 8))
ax1 = fig.add_subplot(111)
# ax1.scatter(data[0], data[1], marker='o', c='b', s=data[2], label='the data')
ax1.scatter(x_data,y_data,marker='o', c='r', alpha=0.3)
for i in range(N_MIXES):
    ax1.scatter(x_test, mus[:,i], marker='o', s=200*sigs[:,i]*pis[:,i],alpha=0.3)
plt.show()
